# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset = dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test =train_test_split(indep , dep , test_size = 0.30 , random_state =0 )

# %%
X_train
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 1163   18   28         0         0           0
# 196    39   32         0         0           0
# 438    52   46         5         0           0
# 183    44   26         0         0           0
# 1298   33   27         2         1           0
# ...   ...  ...       ...       ...         ...
# 763    27   26         0         1           0
# 835    42   35         2         1           0
# 1216   40   25         0         1           0
# 559    19   35         0         1           0
# 684    33   18         1         0           0
#
# [936 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
scy=StandardScaler()
y_train=scy.fit_transform(y_train)
y_test=scy.fit_transform(y_test)

# %%
X_train
# Out:
# array([[-1.5330973 , -0.36100765, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.278355  , -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.51612426,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.84052963, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.75787698, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.95941426, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.svm import SVR
regressor=SVR(kernel="rbf",C= 1000 )
regressor.fit(X_train,y_train)
# Out:
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1000)

# %%
regressor.intercept_
# Out:
# array([0.40052925])

# %%
regressor.n_support_
# Out:
# array([415])

# %%
regressor.support_
# Out:
# array([  2,   3,   4,   6,   8,   9,  12,  13,  15,  21,  22,  25,  26,
#         28,  29,  30,  33,  36,  37,  39,  41,  44,  45,  46,  47,  48,
#         52,  58,  59,  61,  66,  68,  69,  70,  71,  72,  75,  76,  85,
#         90,  91,  92,  98, 100, 104, 105, 107, 113, 117, 121, 123, 125,
#        126, 129, 132, 138, 147, 149, 153, 158, 162, 165, 168, 169, 174,
#        177, 178, 179, 183, 192, 193, 195, 197, 199, 200, 202, 203, 204,
#        206, 207, 209, 211, 212, 213, 214, 215, 218, 220, 223, 226, 227,
#        231, 233, 235, 236, 237, 238, 239, 241, 243, 245, 251, 253, 259,
#        263, 264, 266, 267, 274, 275, 279, 281, 286, 293, 295, 296, 297,
#        300, 308, 309, 312, 317, 319, 321, 322, 323, 326, 331, 334, 335,
#        337, 338, 340, 343, 344, 345, 347, 348, 349, 351, 353, 357, 360,
#        361, 363, 364, 365, 369, 370, 373, 375, 376, 382, 386, 387, 388,
#        389, 391, 392, 395, 398, 399, 400, 401, 410, 412, 413, 418, 420,
#        421, 422, 423, 424, 426, 427, 428, 430, 433, 436, 437, 441, 442,
#        444, 445, 446, 447, 448, 449, 450, 452, 453, 454, 458, 459, 460,
#        462, 464, 468, 470, 472, 474, 477, 481, 484, 486, 487, 489, 490,
#        491, 492, 493, 494, 495, 499, 505, 507, 510, 512, 513, 514, 518,
#        519, 522, 523, 527, 528, 530, 532, 535, 536, 537, 538, 540, 541,
#        543, 544, 545, 548, 549, 550, 551, 553, 554, 558, 560, 562, 563,
#        564, 566, 568, 569, 570, 573, 575, 576, 579, 582, 583, 584, 585,
#        587, 589, 590, 593, 596, 598, 601, 603, 604, 605, 606, 607, 608,
#        611, 612, 615, 622, 623, 624, 625, 628, 634, 639, 645, 647, 648,
#        649, 653, 655, 656, 657, 658, 661, 662, 666, 670, 674, 676, 678,
#        680, 682, 685, 688, 689, 696, 698, 700, 701, 702, 708, 710, 713,
#        717, 724, 725, 727, 729, 730, 731, 734, 735, 737, 738, 744, 745,
#        748, 750, 751, 753, 758, 761, 762, 768, 774, 776, 777, 779, 780,
#        781, 783, 784, 786, 790, 794, 795, 797, 798, 799, 800, 801, 802,
#        805, 806, 807, 808, 809, 811, 813, 815, 817, 825, 826, 827, 828,
#        830, 831, 833, 834, 837, 838, 839, 842, 844, 846, 847, 848, 849,
#        850, 852, 853, 855, 856, 859, 860, 862, 865, 866, 868, 870, 873,
#        875, 876, 877, 880, 881, 884, 888, 890, 895, 897, 898, 900, 904,
#        906, 908, 909, 910, 911, 915, 927, 928, 929, 930, 933, 935])

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test , y_pred)

# %%
r_score
# Out:
# 0.7751778444848028

# %%
import pickle
filename="finalised_model_insurance_SVR.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
preinput=sc.transform([[30,20.5,1,0,1]])

#### age , bmi , children , sex male 0 or 1 , smoker 0 or 1
# Out:
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-0.60861309, -1.63810299, -0.10502969, -1.09394758,  1.94569121]])

# %%
loaded_model=pickle.load(open("finalised_model_insurance_SVR.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([0.38144441])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[18174.18567847]])
