# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(indep , dep , test_size = 1/3 ,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['absolute_error','squared_error'],
             'max_features':['sqrt', 'log2','None'],
              'n_estimators':[10 ,100] }

grid=GridSearchCV(RandomForestRegressor() , param_grid , refit =True , verbose= 3 , n_jobs = -1 )

grid.fit (X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.7688378  0.80267729 0.78604031 0.79772521        nan        nan
#  0.77391484 0.79174431 0.77514513 0.79768645        nan        nan]
#   warnings.warn(
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error'],
#                          'max_features': ['sqrt', 'log2', 'None'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
GridSearchCV(cv='warn', error_score='raise-deprecating',
                estimator=RandomForestRegressor(bootstrap=True, criterion='absolute_error',
                                                max_depth=None,
                                                max_features='auto',
                                                max_leaf_nodes=None,
                                                min_impurity_decrease=0.0,
                                                min_samples_leaf=1,
                                                min_samples_split=2,
                                                min_weight_fraction_leaf=0.0,
                                                n_estimators=100, n_jobs=None,
                                                oob_score=False, random_state=None,
                                                verbose=0, warm_start=False),
                                                 n_jobs=-1,
                param_grid={'criterion': ['absolute_error', 'squared_error'],
                            'max_features': ['auto', 'sqrt', 'log2'],
                            'n_estimators': [10, 100]},
                                pre_dispatch= '2*n_jobs', refit=True, return_train_score=False,
                                scoring=None, verbose=3 )
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestRegressor(criterion='absolute_error',
#                                              max_features='auto'),
#              n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(X_test)

from sklearn.metrics import r2_score
r_score = r2_score(y_test,grid_predictions)

print("The R Score value of the best parameter {} :" .format(grid.best_params_),r_score)
# Out:
# The R Score value of the best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100} : 0.8723666670803771

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.065086      0.003748         0.003767        0.000816
# 1        0.625641      0.024314         0.008079        0.000064
# 2        0.066444      0.003469         0.004230        0.001203
# 3        0.736646      0.019591         0.007952        0.002151
# 4        0.001553      0.000783         0.000000        0.000000
# 5        0.000421      0.000842         0.000000        0.000000
# 6        0.023762      0.001028         0.003010        0.001099
# 7        0.265894      0.042489         0.009066        0.000715
# 8        0.024351      0.002068         0.002715        0.000764
# 9        0.204082      0.015067         0.006460        0.003894
# 10       0.000418      0.000836         0.000000        0.000000
# 11       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features  param_n_estimators  \
# 0   absolute_error               sqrt                  10
# 1   absolute_error               sqrt                 100
# 2   absolute_error               log2                  10
# 3   absolute_error               log2                 100
# 4   absolute_error               None                  10
# 5   absolute_error               None                 100
# 6    squared_error               sqrt                  10
# 7    squared_error               sqrt                 100
# 8    squared_error               log2                  10
# 9    squared_error               log2                 100
# 10   squared_error               None                  10
# 11   squared_error               None                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...           0.786113
# 1   {'criterion': 'absolute_error', 'max_features'...           0.806222
# 2   {'criterion': 'absolute_error', 'max_features'...           0.786149
# 3   {'criterion': 'absolute_error', 'max_features'...           0.798597
# 4   {'criterion': 'absolute_error', 'max_features'...                NaN
# 5   {'criterion': 'absolute_error', 'max_features'...                NaN
# 6   {'criterion': 'squared_error', 'max_features':...           0.786869
# 7   {'criterion': 'squared_error', 'max_features':...           0.803316
# 8   {'criterion': 'squared_error', 'max_features':...           0.785176
# 9   {'criterion': 'squared_error', 'max_features':...           0.809468
# 10  {'criterion': 'squared_error', 'max_features':...                NaN
# 11  {'criterion': 'squared_error', 'max_features':...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.760537           0.809761           0.764533
# 1            0.775690           0.833941           0.838792
# 2            0.774031           0.832042           0.786119
# 3            0.767650           0.835904           0.827337
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.714747           0.819479           0.822471
# 7            0.759881           0.826788           0.815586
# 8            0.753148           0.817958           0.789154
# 9            0.765664           0.832380           0.825247
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.723245         0.768838        0.028773                8
# 1            0.758741         0.802677        0.031474                1
# 2            0.751861         0.786040        0.026186                5
# 3            0.759139         0.797725        0.030753                2
# 4                 NaN              NaN             NaN                9
# 5                 NaN              NaN             NaN                9
# 6            0.726008         0.773915        0.045601                7
# 7            0.753150         0.791744        0.029783                4
# 8            0.730289         0.775145        0.030416                6
# 9            0.755674         0.797686        0.031281                3
# 10                NaN              NaN             NaN                9
# 11                NaN              NaN             NaN                9

# %%
age_input=int(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=int(input("Children :"))
sex_male_input=int(input("Sex Male 0 or 1 :"))
smoker_yes_input=int(input("Smoker yes 0 or 1 :"))
# Out:
# Age: 25
# BMI: 20
# Children : 1
# Sex Male 0 or 1 : 0
# Smoker yes 0 or 1 : 0

# %%
Future_Prediction=grid.predict([[age_input , bmi_input , children_input , sex_male_input , smoker_yes_input]])

print("Future Prediction {}".format(Future_Prediction))
# Out:
# Future Prediction [13981.325]
