# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(indep , dep , test_size= 1/3 , random_state=0 )

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform (X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion': ['absolute_error','squared_error','friedman_mse' ] ,
              'max_features': ['auto','sqrt','log2'],
               'splitter': ['best','random']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param_grid ,refit = True , verbose=3 , n_jobs=-1)

grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 19 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 11 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ravi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.59257986 0.63610687 0.55098442 0.6148287
#         nan        nan 0.58080904 0.5073444  0.52430367 0.58979566
#         nan        nan 0.55300431 0.5375417  0.62080964 0.59771196]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'squared_error',
#                                        'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value of the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value of the best parameter{'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}: 0.7017528149208083

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001943      0.001466         0.000000        0.000000
# 1        0.000410      0.000820         0.000000        0.000000
# 2        0.013808      0.001537         0.002576        0.000918
# 3        0.010159      0.001154         0.002433        0.001038
# 4        0.012376      0.000422         0.002411        0.001025
# 5        0.010167      0.001514         0.002361        0.000456
# 6        0.001204      0.000983         0.000000        0.000000
# 7        0.000533      0.000475         0.000000        0.000000
# 8        0.003646      0.000368         0.001821        0.000987
# 9        0.003059      0.001182         0.002049        0.001198
# 10       0.003061      0.000985         0.002399        0.000614
# 11       0.002431      0.001026         0.002352        0.000554
# 12       0.001205      0.000984         0.000000        0.000000
# 13       0.000000      0.000000         0.000000        0.000000
# 14       0.003521      0.000908         0.001647        0.000827
# 15       0.002553      0.001091         0.001883        0.000445
# 16       0.002648      0.000869         0.002310        0.000874
# 17       0.002559      0.001366         0.002640        0.001387
#
#    param_criterion param_max_features param_splitter  \
# 0   absolute_error               auto           best
# 1   absolute_error               auto         random
# 2   absolute_error               sqrt           best
# 3   absolute_error               sqrt         random
# 4   absolute_error               log2           best
# 5   absolute_error               log2         random
# 6    squared_error               auto           best
# 7    squared_error               auto         random
# 8    squared_error               sqrt           best
# 9    squared_error               sqrt         random
# 10   squared_error               log2           best
# 11   squared_error               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'absolute_error', 'max_features'...                NaN
# 1   {'criterion': 'absolute_error', 'max_features'...                NaN
# 2   {'criterion': 'absolute_error', 'max_features'...           0.721416
# 3   {'criterion': 'absolute_error', 'max_features'...           0.666061
# 4   {'criterion': 'absolute_error', 'max_features'...           0.713228
# 5   {'criterion': 'absolute_error', 'max_features'...           0.599639
# 6   {'criterion': 'squared_error', 'max_features':...                NaN
# 7   {'criterion': 'squared_error', 'max_features':...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...           0.626268
# 9   {'criterion': 'squared_error', 'max_features':...           0.511716
# 10  {'criterion': 'squared_error', 'max_features':...           0.425486
# 11  {'criterion': 'squared_error', 'max_features':...           0.543862
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.561284
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.502392
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.696728
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.618699
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.476904           0.524028           0.642198
# 3            0.564432           0.719021           0.549517
# 4            0.486817           0.267897           0.621286
# 5            0.510206           0.711050           0.644336
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.421744           0.616514           0.754367
# 9            0.625391           0.441490           0.316966
# 10           0.571028           0.732881           0.289670
# 11           0.542095           0.725492           0.514554
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.529129           0.396027           0.617769
# 15           0.469582           0.747389           0.420748
# 16           0.555255           0.656311           0.562860
# 17           0.543961           0.630272           0.627950
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.598353         0.592580        0.086226                5
# 3            0.681503         0.636107        0.067034                1
# 4            0.665694         0.550984        0.160424                9
# 5            0.608913         0.614829        0.065331                3
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.485153         0.580809        0.116547                7
# 9            0.641158         0.507344        0.120367               12
# 10           0.602453         0.524304        0.152717               11
# 11           0.622975         0.589796        0.076891                6
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.660812         0.553004        0.090661                8
# 15           0.547598         0.537542        0.112811               10
# 16           0.632894         0.620810        0.054453                2
# 17           0.567678         0.597712        0.035231                4

# %%
age_input=int(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1 :"))
smoker_yes_input = int(input("Smoker Yes 0 or 1 :"))
# Out:
# Age: 25
# BMI: 20.9
# Children: 0
# Sex Male 0 or 1 : 0
# Smoker Yes 0 or 1 : 0

# %% [markdown]
# ##### Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# print("Future Predictions = {} ".format(Future_Prediction))
